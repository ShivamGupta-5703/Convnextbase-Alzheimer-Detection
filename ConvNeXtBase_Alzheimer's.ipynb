# %%
# !mkdir result
# !mkdir images
# !mkdir images/misclassified

# %%
import os
import numpy as np
import threading as th
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt
import sklearn.metrics as metric
from keras import models, layers
from keras.utils import image_dataset_from_directory as IDFD
from sklearn.metrics import ConfusionMatrixDisplay as CMD, classification_report

from keras.applications import (ConvNeXtBase)
# Out:
# 2024-02-21 15:55:01.225045: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
#
# 2024-02-21 15:55:01.225145: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
#
# 2024-02-21 15:55:01.350126: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# test for GPU use in tensorflow
physical_gpus = tf.config.list_physical_devices('GPU')
print(physical_gpus)

# define variables and constants
IMAGE_SIZE = (176, 208)
BATCH_SIZE = 32
EPOCHS = 30

BASE_DIR = './'
IMAGE_DIR = BASE_DIR + 'images/'
MODEL_DIR = BASE_DIR + 'models/'
RESULTS_DIR = BASE_DIR + 'result/'
DATASET_DIR = "/kaggle/input/Alzheimer_s Dataset/"
USE_CPU = False

if USE_CPU:
    tf.config.set_visible_devices([], 'GPU')

print("Tensorflow version", tf.__version__)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Tensorflow version 2.15.0

# %%
class_names = [filename for filename in os.listdir(DATASET_DIR+'train')]
class_names
# Out:
# ['ModerateDemented', 'NonDemented', 'VeryMildDemented', 'MildDemented']

# %%
def load(directory, image_size, batch_size, verbose=False):
    class_names = ["Mild_Demented", "Moderate_Demented", "Non_Demented", "Very_Mild_Demented"]
    train_ds = IDFD(directory+"train",
                    seed=7891,
                    validation_split=0.13,
                    subset="training",
                    labels="inferred",
                    label_mode="categorical",
                    interpolation="bilinear",
                    image_size=image_size,
                    batch_size=batch_size,
                    color_mode='rgb')

    test_ds = IDFD(directory+"train",
                   seed=7891,
                   validation_split=0.13,
                   subset="validation",
                   labels="inferred",
                   label_mode="categorical",
                   interpolation="bilinear",
                   image_size=image_size,
                   batch_size=batch_size,
                   color_mode='rgb')

    val_ds = IDFD(directory+"test",
                  seed=7891,
                  labels="inferred",
                  label_mode="categorical",
                  interpolation="bilinear",
                  image_size=image_size,
                  batch_size=batch_size,
                  color_mode='rgb',
                  shuffle=False)

    if verbose:
        train = np.concatenate([np.argmax(l,axis=1) for x,l in train_ds], axis=0)
        val = np.concatenate([np.argmax(l,axis=1) for x,l in val_ds], axis=0)
        test = np.concatenate([np.argmax(l,axis=1) for x,l in test_ds], axis=0)

        print()
        print("Summary:")
        print("--------------------------------")
        print()
        print("Dataset Classes: ", class_names)
        print()
        print("Dataset split:")
        print("--------------------------------")
        print("Using ", len(train), " files for training")
        print("Using ", len(val), " files for validation")
        print("Using ", len(test), " files for testing")
        print()
        print("Images per label in each set:")
        print("--------------------------------")

        print("Training: ")
        for i,c in enumerate(class_names):
            print("   ", np.count_nonzero(train==i), c)

        print("Validation: ")
        for i,c in enumerate(class_names):
            print("   ", np.count_nonzero(val==i), c)

        print("Test: ")
        for i,c in enumerate(class_names):
            print("   ", np.count_nonzero(test==i), c)

        # show sample images
        plt.figure(figsize=(10, 10))
        for images, labels in train_ds.take(1):
            for i in range(9):
                ax = plt.subplot(3, 3, i + 1)
                plt.imshow(images[i].numpy().astype("uint8"))
                plt.title(class_names[np.argmax(labels[i])])
                plt.axis("off")

    return train_ds, val_ds, test_ds, class_names

# %%
# plot loss and accuracy graphics

def draw_loss_acc_graphics(outfile, history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc)+1)

    plt.figure()
    plt.plot(epochs, acc, 'b', label='Training acc')
    plt.plot(epochs, val_acc, 'c', label='Validation acc')
    plt.title("Training and Validation Accuracy")
    plt.legend()
    plt.savefig(outfile + '_accuracy_graph.pdf')
    plt.close()

    plt.figure()
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'c', label='Validation loss')
    plt.title("Training and Validation Loss")
    plt.legend()
    plt.savefig(outfile + '_loss_graph.pdf')
    plt.close()

# evaluate model with test set

def process_tests(model, test_ds):
    y_true = np.array([], dtype=np.int32)
    y_pred = np.array([], dtype=np.int32)
    images = []

    for image_batch, labels in test_ds:
        y_true = np.concatenate([y_true, np.argmax(labels.numpy(), axis=-1)])
        y_pred = np.concatenate([y_pred, np.argmax(model.predict(image_batch,verbose=0), axis=-1)])
        for img in image_batch:
            images.append(img)

    size_test = sum([len(l) for _,l in test_ds])
    images = np.reshape(images, (size_test,176,208,3))

    return y_true, y_pred, images

def draw_confusion_matrix(outfile, model, test_ds, class_names):

    # plot confusion matrix
    y_true, y_pred, images = process_tests(model, test_ds)
    plt.figure(figsize=(5, 5))
    cmap = plt.cm.Blues #'viridis'

    # save confusion matrix with classification percentage
    cm = CMD.from_predictions(y_true, y_pred, cmap=cmap, labels=range(len(class_names)),
                              display_labels=class_names, normalize="pred")
    #plt.tight_layout()
    ax = plt.gca()
    plt.setp(ax.yaxis.get_majorticklabels(), rotation=90, ha="center", rotation_mode="anchor")
    plt.savefig(outfile + '_cm.pdf')

    # save confusion matrix with number of samples
    cm = CMD.from_predictions(y_true, y_pred, cmap=cmap,
                              labels=range(len(class_names)),display_labels=class_names)
    plt.savefig(outfile + '_cm2.pdf')
    plt.close()

    # calculate accuracy, precision, recall and F1-score
    accuracy = metric.accuracy_score(y_true, y_pred)
    precision = metric.precision_score(y_true, y_pred, average="macro", zero_division=1)
    recall = metric.recall_score(y_true, y_pred, average="macro")
    f1 = metric.f1_score(y_true, y_pred, average="macro", zero_division=1)
    print('Accuracy | Precision | Recall | F1 score')
    print(accuracy, precision, recall, f1)
    print(metric.precision_recall_fscore_support(y_true, y_pred, average="macro"))

    report = classification_report(
        y_true, y_pred, labels=range(len(class_names)),
        target_names=class_names
    )
    print(report)

    return precision, recall, f1, report

# %%
def save_misclassified_images(outfile, model, test_ds, class_names, n_images=3):

    # save incorrectly classified test images
    y_true, y_pred, images = process_tests(model, test_ds)

    a = np.array(y_true) == np.array(y_pred)
    plt.figure()
    ax=plt.gca()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    j=0
    for i in range(len(a)):
        if not a[i] and j<n_images:
            j=j+1
            plt.imshow(np.array(images[i]).astype("uint8"))
            plt.title(class_names[y_true[i]] + " - " + class_names[y_pred[i]])
            plt.savefig(outfile + '_misclassified_' + str(j) + '.pdf')
    plt.close()

def save_results(filename, model, train_ds, val_ds,
                 test_ds, class_names, history):
    # loss-accuracy graphics
    draw_loss_acc_graphics(IMAGE_DIR+filename, history)

    # confusion matrix
    precision, recall, f1, report = draw_confusion_matrix(IMAGE_DIR+filename, model, test_ds, class_names)

    # misclassified images
    save_misclassified_images(IMAGE_DIR+'misclassified/'+filename, model, test_ds, class_names)

    # save results to file
    train_loss, train_acc = model.evaluate(train_ds)
    val_loss, val_acc     = model.evaluate(val_ds)
    test_loss, test_acc   = model.evaluate(test_ds)

    with open(RESULTS_DIR+filename+'.txt', 'w') as f:
        f.write("Training loss/accuracy: " + str(train_loss) + ', ' + str(train_acc) + '\n')
        f.write("Validate loss/accuracy: " + str(val_loss) + ', ' + str(val_acc) + '\n')
        f.write("Testing  loss/accuracy: " + str(test_loss) + ', ' + str(test_acc) + '\n')
        f.write("Precision: " + str(precision) + '\n')
        f.write("Recall: " + str(recall) + '\n')
        f.write("F1: " + str(f1) + '\n')
        f.write(report + '\n')

# %%
# this module creates objects of the different models

def build_cnn_model(model, num_classes,
                    transfer_learning, batch_size):
    weights = None
    trainable = True
    include_top = True
    
    if transfer_learning:
        weights = "imagenet"
        trainable = False
        include_top = False


    model.add(ConvNeXtBase(weights=weights, include_top=include_top,
                                 input_shape=(176,208,3),classes=num_classes))


    model.layers[-1].trainable = trainable

    return model


def create_model(num_classes, data_augmentation, transfer_learning, batch_size=32):
    # base model
    model = models.Sequential()
    model.add(layers.Input(shape=(176,208,3)))

    # data augmentation
    if data_augmentation:
        model.add(layers.RandomFlip("horizontal"))
        model.add(layers.RandomRotation(0.1, fill_mode='constant',fill_value=-1.0))
        model.add(layers.RandomZoom((-0.2,0.2), fill_mode='constant',fill_value=-1.0))

    model = build_cnn_model(model, num_classes,
                            transfer_learning, batch_size)

    # MLP on top
    if transfer_learning:
        model.add(layers.Flatten())
        model.add(layers.Dropout(0.5))
        model.add(layers.Dense(num_classes, activation='softmax'))

    model.compile(loss="categorical_crossentropy",
                  optimizer="adam", metrics=["accuracy"])

    return model

# %%
def run_experiments(train_ds, val_ds, test_ds, class_names,
                    epochs, s="", data_augmentation=False, transfer_learning=False):
    
    model = create_model(len(class_names), data_augmentation, transfer_learning, BATCH_SIZE)

    model.summary()

    history = model.fit(train_ds,
                        epochs=epochs,
                        validation_data=val_ds,
                        verbose=1)

    model.save("ConvNeXtBase"+s+".keras")
    

    # save model to disk
    filename = "ConvNeXtBase" + '_' + s

    # save results and graphics to disk
    save_results(filename, model, train_ds,
                 val_ds, test_ds, class_names, history)
        

def experiments_with_dataset(train_ds, val_ds, test_ds, class_names):

    print("Number of classes", len(class_names))

    # training from scratch
    print('  ## training from scratch')
    run_experiments(train_ds, val_ds, test_ds, class_names, EPOCHS, 
                    s="_scratch", data_augmentation=False, transfer_learning=False)

    # using data augmentation
    print('  ## training with data augmentation')
    run_experiments(train_ds, val_ds, test_ds, class_names, EPOCHS,
                    s="_da", data_augmentation=True, transfer_learning=False)

    # using transfer learning
    print('  ## training with transfer learning')
    run_experiments(train_ds, val_ds, test_ds, class_names, EPOCHS,
                    s="_tl", data_augmentation=False, transfer_learning=True)
            
    # using transfer learning and data augmentation
    print('  ## training with transfer learning and data augmentation')
    run_experiments(train_ds, val_ds, test_ds, class_names, EPOCHS, 
                    s="_datl", data_augmentation=True, transfer_learning=True)

# %%
# experiments with Figshare
print('\nProcessing Alzihmers Dataset:')
print('--------------------------------')

train_ds, val_ds, test_ds, class_names = load(DATASET_DIR, IMAGE_SIZE, BATCH_SIZE, False)
experiments_with_dataset(train_ds, val_ds, test_ds, class_names)
# Out:
# Processing Alzihmers Dataset:
#
# --------------------------------
# Found 5121 files belonging to 4 classes.
# Using 4456 files for training.
# Found 5121 files belonging to 4 classes.
# Using 665 files for validation.
# Found 1279 files belonging to 4 classes.
# Number of classes 4
#
#   ## training from scratch
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  convnext_base (Functional)  (None, 4)                 87570564
#
# =================================================================
# Total params: 87570564 (334.06 MB)
# Trainable params: 87570564 (334.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
#
# I0000 00:00:1708530971.750720      78 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#   1/140 [..............................] - ETA: 2:54:22 - loss: 1.9283 - accuracy: 0.156
#   2/140 [..............................] - ETA: 1:40 - loss: 8.7259 - accuracy: 0.2500
#   3/140 [..............................] - ETA: 1:39 - loss: 8.7581 - accuracy: 0.29
#   4/140 [..............................] - ETA: 1:39 - loss: 7.0495 - accuracy: 0.35
#   5/140 [>.............................] - ETA: 1:38 - loss: 5.9032 - accuracy: 0.41
#   6/140 [>.............................] - ETA: 1:37 - loss: 5.1096 - accuracy: 0.42
#   7/140 [>.............................] - ETA: 1:36 - loss: 4.5718 - accuracy: 0.41
#   8/140 [>.............................] - ETA: 1:36 - loss: 4.1476 - accuracy: 0.41
#   9/140 [>.............................] - ETA: 1:35 - loss: 3.7962 - accuracy: 0.41
#  10/140 [=>............................] - ETA: 1:34 - loss: 3.5294 - accuracy: 0.41
#  11/140 [=>............................] - ETA: 1:33 - loss: 3.3221 - accuracy: 0.41
#  12/140 [=>............................] - ETA: 1:33 - loss: 3.3550 - accuracy: 0.41
#  13/140 [=>............................] - ETA: 1:32 - loss: 3.1825 - accuracy: 0.39
#  14/140 [==>...........................] - ETA: 1:31 - loss: 3.0426 - accuracy: 0.39
#  15/140 [==>...........................] - ETA: 1:30 - loss: 2.9882 - accuracy: 0.40
#  16/140 [==>...........................] - ETA: 1:30 - loss: 2.8580 - accuracy: 0.41
#  17/140 [==>...........................] - ETA: 1:29 - loss: 2.8282 - accuracy: 0.41
#  18/140 [==>...........................] - ETA: 1:28 - loss: 2.7137 - accuracy: 0.43
#  19/140 [===>..........................] - ETA: 1:28 - loss: 2.6201 - accuracy: 0.43
#  20/140 [===>..........................] - ETA: 1:27 - loss: 2.5960 - accuracy: 0.43
#  21/140 [===>..........................] - ETA: 1:26 - loss: 2.5231 - accuracy: 0.43
#  22/140 [===>..........................] - ETA: 1:25 - loss: 2.4626 - accuracy: 0.43
#  23/140 [===>..........................] - ETA: 1:25 - loss: 2.3980 - accuracy: 0.43
#  24/140 [====>.........................] - ETA: 1:24 - loss: 2.3419 - accuracy: 0.43
#  25/140 [====>.........................] - ETA: 1:23 - loss: 2.2910 - accuracy: 0.43
#  26/140 [====>.........................] - ETA: 1:23 - loss: 2.2792 - accuracy: 0.44
#  27/140 [====>.........................] - ETA: 1:22 - loss: 2.2297 - accuracy: 0.44
#  28/140 [=====>........................] - ETA: 1:21 - loss: 2.1810 - accuracy: 0.44
#  29/140 [=====>........................] - ETA: 1:20 - loss: 2.1334 - accuracy: 0.45
#  30/140 [=====>........................] - ETA: 1:20 - loss: 2.0929 - accuracy: 0.45
#  31/140 [=====>........................] - ETA: 1:19 - loss: 2.0541 - accuracy: 0.45
#  32/140 [=====>........................] - ETA: 1:18 - loss: 2.0158 - accuracy: 0.46
#  33/140 [======>.......................] - ETA: 1:17 - loss: 1.9818 - accuracy: 0.46
#  34/140 [======>.......................] - ETA: 1:17 - loss: 1.9865 - accuracy: 0.46
#  35/140 [======>.......................] - ETA: 1:16 - loss: 1.9894 - accuracy: 0.45
#  36/140 [======>.......................] - ETA: 1:15 - loss: 1.9585 - accuracy: 0.46
#  37/140 [======>.......................] - ETA: 1:15 - loss: 1.9431 - accuracy: 0.45
#  38/140 [=======>......................] - ETA: 1:14 - loss: 1.9181 - accuracy: 0.45
#  39/140 [=======>......................] - ETA: 1:13 - loss: 1.9238 - accuracy: 0.45
#  40/140 [=======>......................] - ETA: 1:12 - loss: 1.9043 - accuracy: 0.45
#  41/140 [=======>......................] - ETA: 1:12 - loss: 1.8802 - accuracy: 0.45
#  42/140 [========>.....................] - ETA: 1:11 - loss: 1.8546 - accuracy: 0.45
#  43/140 [========>.....................] - ETA: 1:10 - loss: 1.8338 - accuracy: 0.46
#  44/140 [========>.....................] - ETA: 1:09 - loss: 1.8089 - accuracy: 0.46
#  45/140 [========>.....................] - ETA: 1:09 - loss: 1.8239 - accuracy: 0.46
#  46/140 [========>.....................] - ETA: 1:08 - loss: 1.8537 - accuracy: 0.46
#  47/140 [=========>....................] - ETA: 1:07 - loss: 1.8538 - accuracy: 0.46
#  48/140 [=========>....................] - ETA: 1:07 - loss: 1.8322 - accuracy: 0.47
#  49/140 [=========>....................] - ETA: 1:06 - loss: 1.8126 - accuracy: 0.47
#  50/140 [=========>....................] - ETA: 1:05 - loss: 1.7935 - accuracy: 0.47
#  51/140 [=========>....................] - ETA: 1:04 - loss: 1.7758 - accuracy: 0.47
#  52/140 [==========>...................] - ETA: 1:04 - loss: 1.7593 - accuracy: 0.47
#  53/140 [==========>...................] - ETA: 1:03 - loss: 1.7405 - accuracy: 0.47
#  54/140 [==========>...................] - ETA: 1:02 - loss: 1.7253 - accuracy: 0.47
#  55/140 [==========>...................] - ETA: 1:01 - loss: 1.7112 - accuracy: 0.47
#  56/140 [===========>..................] - ETA: 1:01 - loss: 1.6964 - accuracy: 0.48
#  57/140 [===========>..................] - ETA: 1:00 - loss: 1.6826 - accuracy: 0.48
#  58/140 [===========>..................] - ETA: 59s - loss: 1.6699 - accuracy: 0.4844
#  59/140 [===========>..................] - ETA: 58s - loss: 1.6746 - accuracy: 0.483
#  60/140 [===========>..................] - ETA: 58s - loss: 1.6780 - accuracy: 0.484
#  61/140 [============>.................] - ETA: 57s - loss: 1.6681 - accuracy: 0.483
#  62/140 [============>.................] - ETA: 56s - loss: 1.6570 - accuracy: 0.482
#  63/140 [============>.................] - ETA: 56s - loss: 1.6556 - accuracy: 0.484
#  64/140 [============>.................] - ETA: 55s - loss: 1.6440 - accuracy: 0.485
#  65/140 [============>.................] - ETA: 54s - loss: 1.6542 - accuracy: 0.487
#  66/140 [=============>................] - ETA: 53s - loss: 1.6487 - accuracy: 0.489
#  67/140 [=============>................] - ETA: 53s - loss: 1.6403 - accuracy: 0.490
#  68/140 [=============>................] - ETA: 52s - loss: 1.6493 - accuracy: 0.489
#  69/140 [=============>................] - ETA: 51s - loss: 1.6390 - accuracy: 0.489
#  70/140 [==============>...............] - ETA: 51s - loss: 1.6305 - accuracy: 0.487
#  71/140 [==============>...............] - ETA: 50s - loss: 1.6218 - accuracy: 0.486
#  72/140 [==============>...............] - ETA: 49s - loss: 1.6160 - accuracy: 0.485
#  73/140 [==============>...............] - ETA: 48s - loss: 1.6055 - accuracy: 0.484
#  74/140 [==============>...............] - ETA: 48s - loss: 1.5959 - accuracy: 0.484
#  75/140 [===============>..............] - ETA: 47s - loss: 1.5877 - accuracy: 0.484
#  76/140 [===============>..............] - ETA: 46s - loss: 1.5792 - accuracy: 0.483
#  77/140 [===============>..............] - ETA: 45s - loss: 1.5678 - accuracy: 0.485
#  78/140 [===============>..............] - ETA: 45s - loss: 1.5586 - accuracy: 0.486
#  79/140 [===============>..............] - ETA: 44s - loss: 1.5560 - accuracy: 0.484
#  80/140 [================>.............] - ETA: 43s - loss: 1.5456 - accuracy: 0.485
#  81/140 [================>.............] - ETA: 42s - loss: 1.5367 - accuracy: 0.486
#  82/140 [================>.............] - ETA: 42s - loss: 1.5286 - accuracy: 0.487
#  83/140 [================>.............] - ETA: 41s - loss: 1.5213 - accuracy: 0.486
#  84/140 [=================>............] - ETA: 40s - loss: 1.5163 - accuracy: 0.485
#  85/140 [=================>............] - ETA: 40s - loss: 1.5095 - accuracy: 0.486
#  86/140 [=================>............] - ETA: 39s - loss: 1.5016 - accuracy: 0.488
#  87/140 [=================>............] - ETA: 38s - loss: 1.4955 - accuracy: 0.489
#  88/140 [=================>............] - ETA: 37s - loss: 1.4903 - accuracy: 0.490
#  89/140 [==================>...........] - ETA: 37s - loss: 1.4856 - accuracy: 0.490
#  90/140 [==================>...........] - ETA: 36s - loss: 1.4794 - accuracy: 0.491
#  91/140 [==================>...........] - ETA: 35s - loss: 1.4737 - accuracy: 0.491
#  92/140 [==================>...........] - ETA: 34s - loss: 1.4675 - accuracy: 0.493
#  93/140 [==================>...........] - ETA: 34s - loss: 1.4612 - accuracy: 0.495
#  94/140 [===================>..........] - ETA: 33s - loss: 1.4553 - accuracy: 0.496
#  95/140 [===================>..........] - ETA: 32s - loss: 1.4510 - accuracy: 0.496
#  96/140 [===================>..........] - ETA: 32s - loss: 1.4438 - accuracy: 0.497
#  97/140 [===================>..........] - ETA: 31s - loss: 1.4381 - accuracy: 0.497
#  98/140 [====================>.........] - ETA: 30s - loss: 1.4348 - accuracy: 0.496
#  99/140 [====================>.........] - ETA: 29s - loss: 1.4271 - accuracy: 0.498
# 100/140 [====================>.........] - ETA: 29s - loss: 1.4237 - accuracy: 0.499
# 101/140 [====================>.........] - ETA: 28s - loss: 1.4186 - accuracy: 0.498
# 102/140 [====================>.........] - ETA: 27s - loss: 1.4130 - accuracy: 0.498
# 103/140 [=====================>........] - ETA: 26s - loss: 1.4075 - accuracy: 0.498
# 104/140 [=====================>........] - ETA: 26s - loss: 1.4046 - accuracy: 0.499
# 105/140 [=====================>........] - ETA: 25s - loss: 1.4009 - accuracy: 0.499
# 106/140 [=====================>........] - ETA: 24s - loss: 1.3954 - accuracy: 0.502
# 107/140 [=====================>........] - ETA: 24s - loss: 1.3905 - accuracy: 0.501
# 108/140 [======================>.......] - ETA: 23s - loss: 1.3870 - accuracy: 0.500
# 109/140 [======================>.......] - ETA: 22s - loss: 1.3839 - accuracy: 0.501
# 110/140 [======================>.......] - ETA: 21s - loss: 1.3799 - accuracy: 0.500
# 111/140 [======================>.......] - ETA: 21s - loss: 1.3760 - accuracy: 0.500
# 112/140 [=======================>......] - ETA: 20s - loss: 1.3716 - accuracy: 0.500
# 113/140 [=======================>......] - ETA: 19s - loss: 1.3665 - accuracy: 0.501
# 114/140 [=======================>......] - ETA: 18s - loss: 1.3629 - accuracy: 0.501
# 115/140 [=======================>......] - ETA: 18s - loss: 1.3588 - accuracy: 0.501
# 116/140 [=======================>......] - ETA: 17s - loss: 1.3545 - accuracy: 0.500
# 117/140 [========================>.....] - ETA: 16s - loss: 1.3519 - accuracy: 0.501
# 118/140 [========================>.....] - ETA: 16s - loss: 1.3475 - accuracy: 0.502
# 119/140 [========================>.....] - ETA: 15s - loss: 1.3440 - accuracy: 0.503
# 120/140 [========================>.....] - ETA: 14s - loss: 1.3414 - accuracy: 0.503
# 121/140 [========================>.....] - ETA: 13s - loss: 1.3379 - accuracy: 0.502
# 122/140 [=========================>....] - ETA: 13s - loss: 1.3342 - accuracy: 0.502
# 123/140 [=========================>....] - ETA: 12s - loss: 1.3304 - accuracy: 0.503
# 124/140 [=========================>....] - ETA: 11s - loss: 1.3275 - accuracy: 0.504
# 125/140 [=========================>....] - ETA: 10s - loss: 1.3241 - accuracy: 0.504
# 126/140 [==========================>...] - ETA: 10s - loss: 1.3193 - accuracy: 0.505
# 127/140 [==========================>...] - ETA: 9s - loss: 1.3167 - accuracy: 0.505
# 128/140 [==========================>...] - ETA: 8s - loss: 1.3134 - accuracy: 0.50
# 129/140 [==========================>...] - ETA: 8s - loss: 1.3096 - accuracy: 0.50
# 130/140 [==========================>...] - ETA: 7s - loss: 1.3070 - accuracy: 0.50
# 131/140 [===========================>..] - ETA: 6s - loss: 1.3041 - accuracy: 0.50
# 132/140 [===========================>..] - ETA: 5s - loss: 1.3024 - accuracy: 0.50
# 133/140 [===========================>..] - ETA: 5s - loss: 1.2983 - accuracy: 0.50
# 134/140 [===========================>..] - ETA: 4s - loss: 1.2941 - accuracy: 0.50
# 135/140 [===========================>..] - ETA: 3s - loss: 1.2905 - accuracy: 0.51
# 136/140 [============================>.] - ETA: 2s - loss: 1.2888 - accuracy: 0.50
# 137/140 [============================>.] - ETA: 2s - loss: 1.2847 - accuracy: 0.51
# 138/140 [============================>.] - ETA: 1s - loss: 1.2818 - accuracy: 0.51
# 139/140 [============================>.] - ETA: 0s - loss: 1.2798 - accuracy: 0.51
# 140/140 [==============================] - ETA: 0s - loss: 1.2790 - accuracy: 0.51
# 140/140 [==============================] - 203s 920ms/step - loss: 1.2790 - accuracy: 0.5103 - val_loss: 0.9502 - val_accuracy: 0.5246
# Epoch 2/30
#
#   1/140 [..............................] - ETA: 2:02 - loss: 0.8993 - accuracy: 0.56
#   2/140 [..............................] - ETA: 1:40 - loss: 0.8884 - accuracy: 0.59
#   3/140 [..............................] - ETA: 1:40 - loss: 0.8449 - accuracy: 0.63
#   4/140 [..............................] - ETA: 1:39 - loss: 0.8569 - accuracy: 0.61
#   5/140 [>.............................] - ETA: 1:38 - loss: 0.8965 - accuracy: 0.58
#   6/140 [>.............................] - ETA: 1:37 - loss: 0.9637 - accuracy: 0.54
#   7/140 [>.............................] - ETA: 1:36 - loss: 0.9629 - accuracy: 0.54
#   8/140 [>.............................] - ETA: 1:36 - loss: 0.9347 - accuracy: 0.55
#   9/140 [>.............................] - ETA: 1:35 - loss: 0.9313 - accuracy: 0.54
#  10/140 [=>............................] - ETA: 1:34 - loss: 0.9369 - accuracy: 0.54
#  11/140 [=>............................] - ETA: 1:33 - loss: 0.9304 - accuracy: 0.53
#  12/140 [=>............................] - ETA: 1:33 - loss: 0.9229 - accuracy: 0.54
#  13/140 [=>............................] - ETA: 1:32 - loss: 0.9327 - accuracy: 0.53
#  14/140 [==>...........................] - ETA: 1:31 - loss: 0.9334 - accuracy: 0.52
#  15/140 [==>...........................] - ETA: 1:30 - loss: 0.9211 - accuracy: 0.53
#  16/140 [==>...........................] - ETA: 1:30 - loss: 0.9188 - accuracy: 0.53
#  17/140 [==>...........................] - ETA: 1:29 - loss: 0.9185 - accuracy: 0.53
#  18/140 [==>...........................] - ETA: 1:28 - loss: 0.9174 - accuracy: 0.53
#  19/140 [===>..........................] - ETA: 1:27 - loss: 0.9267 - accuracy: 0.52
#  20/140 [===>..........................] - ETA: 1:27 - loss: 0.9240 - accuracy: 0.53
#  21/140 [===>..........................] - ETA: 1:26 - loss: 0.9211 - accuracy: 0.53
#  22/140 [===>..........................] - ETA: 1:25 - loss: 0.9130 - accuracy: 0.54
#  23/140 [===>..........................] - ETA: 1:25 - loss: 0.9084 - accuracy: 0.54
#  24/140 [====>.........................] - ETA: 1:24 - loss: 0.9056 - accuracy: 0.54
#  25/140 [====>.........................] - ETA: 1:23 - loss: 0.9069 - accuracy: 0.53
#  26/140 [====>.........................] - ETA: 1:23 - loss: 0.9084 - accuracy: 0.53
#  27/140 [====>.........................] - ETA: 1:22 - loss: 0.9040 - accuracy: 0.54
#  28/140 [=====>........................] - ETA: 1:21 - loss: 0.9042 - accuracy: 0.54
#  29/140 [=====>........................] - ETA: 1:20 - loss: 0.9037 - accuracy: 0.54
#  30/140 [=====>........................] - ETA: 1:20 - loss: 0.9020 - accuracy: 0.54
#  31/140 [=====>........................] - ETA: 1:19 - loss: 0.9084 - accuracy: 0.53
#  32/140 [=====>........................] - ETA: 1:18 - loss: 0.9079 - accuracy: 0.54
#  33/140 [======>.......................] - ETA: 1:17 - loss: 0.9049 - accuracy: 0.54
#  34/140 [======>.......................] - ETA: 1:17 - loss: 0.9093 - accuracy: 0.54
#  35/140 [======>.......................] - ETA: 1:16 - loss: 0.9069 - accuracy: 0.54
#  36/140 [======>.......................] - ETA: 1:15 - loss: 0.9073 - accuracy: 0.53
#  37/140 [======>.......................] - ETA: 1:14 - loss: 0.9067 - accuracy: 0.53
#  38/140 [=======>......................] - ETA: 1:14 - loss: 0.9043 - accuracy: 0.53
#  39/140 [=======>......................] - ETA: 1:13 - loss: 0.9080 - accuracy: 0.53
#  40/140 [=======>......................] - ETA: 1:12 - loss: 0.9047 - accuracy: 0.53
#  41/140 [=======>......................] - ETA: 1:12 - loss: 0.9027 - accuracy: 0.53
#  42/140 [========>.....................] - ETA: 1:11 - loss: 0.9051 - accuracy: 0.54
#  43/140 [========>.....................] - ETA: 1:10 - loss: 0.9043 - accuracy: 0.54
#  44/140 [========>.....................] - ETA: 1:09 - loss: 0.8987 - accuracy: 0.54
#  45/140 [========>.....................] - ETA: 1:09 - loss: 0.9025 - accuracy: 0.54
#  46/140 [========>.....................] - ETA: 1:08 - loss: 0.9009 - accuracy: 0.54
#  47/140 [=========>....................] - ETA: 1:07 - loss: 0.9009 - accuracy: 0.54
#  48/140 [=========>....................] - ETA: 1:07 - loss: 0.9018 - accuracy: 0.54
#  49/140 [=========>....................] - ETA: 1:06 - loss: 0.9007 - accuracy: 0.54
#  50/140 [=========>....................] - ETA: 1:05 - loss: 0.8981 - accuracy: 0.55
#  51/140 [=========>....................] - ETA: 1:04 - loss: 0.8993 - accuracy: 0.54
#  52/140 [==========>...................] - ETA: 1:04 - loss: 0.9001 - accuracy: 0.54
#  53/140 [==========>...................] - ETA: 1:03 - loss: 0.8974 - accuracy: 0.55
#  54/140 [==========>...................] - ETA: 1:02 - loss: 0.8970 - accuracy: 0.54
#  55/140 [==========>...................] - ETA: 1:01 - loss: 0.8967 - accuracy: 0.55
#  56/140 [===========>..................] - ETA: 1:01 - loss: 0.8969 - accuracy: 0.55
#  57/140 [===========>..................] - ETA: 1:00 - loss: 0.8985 - accuracy: 0.55
#  58/140 [===========>..................] - ETA: 59s - loss: 0.8964 - accuracy: 0.5512
#  59/140 [===========>..................] - ETA: 59s - loss: 0.8973 - accuracy: 0.551
#  60/140 [===========>..................] - ETA: 58s - loss: 0.8952 - accuracy: 0.552
#  61/140 [============>.................] - ETA: 57s - loss: 0.8958 - accuracy: 0.552
#  62/140 [============>.................] - ETA: 56s - loss: 0.8944 - accuracy: 0.553
#  63/140 [============>.................] - ETA: 56s - loss: 0.8988 - accuracy: 0.552
#  64/140 [============>.................] - ETA: 55s - loss: 0.8969 - accuracy: 0.551
#  65/140 [============>.................] - ETA: 54s - loss: 0.9013 - accuracy: 0.550
#  66/140 [=============>................] - ETA: 53s - loss: 0.9051 - accuracy: 0.549
#  67/140 [=============>................] - ETA: 53s - loss: 0.9059 - accuracy: 0.547
#  68/140 [=============>................] - ETA: 52s - loss: 0.9053 - accuracy: 0.548
#  69/140 [=============>................] - ETA: 51s - loss: 0.9057 - accuracy: 0.548
#  70/140 [==============>...............] - ETA: 51s - loss: 0.9062 - accuracy: 0.546
#  71/140 [==============>...............] - ETA: 50s - loss: 0.9062 - accuracy: 0.546
#  72/140 [==============>...............] - ETA: 49s - loss: 0.9041 - accuracy: 0.547
#  73/140 [==============>...............] - ETA: 48s - loss: 0.9038 - accuracy: 0.547
#  74/140 [==============>...............] - ETA: 48s - loss: 0.9049 - accuracy: 0.546
#  75/140 [===============>..............] - ETA: 47s - loss: 0.9092 - accuracy: 0.544
#  76/140 [===============>..............] - ETA: 46s - loss: 0.9092 - accuracy: 0.542
#  77/140 [===============>..............] - ETA: 45s - loss: 0.9082 - accuracy: 0.542
#  78/140 [===============>..............] - ETA: 45s - loss: 0.9073 - accuracy: 0.543
#  79/140 [===============>..............] - ETA: 44s - loss: 0.9066 - accuracy: 0.543
#  80/140 [================>.............] - ETA: 43s - loss: 0.9063 - accuracy: 0.544
#  81/140 [================>.............] - ETA: 43s - loss: 0.9055 - accuracy: 0.545
#  82/140 [================>.............] - ETA: 42s - loss: 0.9021 - accuracy: 0.546
#  83/140 [================>.............] - ETA: 41s - loss: 0.9011 - accuracy: 0.547
#  84/140 [=================>............] - ETA: 40s - loss: 0.9011 - accuracy: 0.547
#  85/140 [=================>............] - ETA: 40s - loss: 0.9021 - accuracy: 0.546
#  86/140 [=================>............] - ETA: 39s - loss: 0.9016 - accuracy: 0.548
#  87/140 [=================>............] - ETA: 38s - loss: 0.9019 - accuracy: 0.548
#  88/140 [=================>............] - ETA: 37s - loss: 0.9006 - accuracy: 0.550
#  89/140 [==================>...........] - ETA: 37s - loss: 0.9042 - accuracy: 0.549
#  90/140 [==================>...........] - ETA: 36s - loss: 0.9033 - accuracy: 0.550
#  91/140 [==================>...........] - ETA: 35s - loss: 0.9032 - accuracy: 0.550
#  92/140 [==================>...........] - ETA: 34s - loss: 0.9024 - accuracy: 0.551
#  93/140 [==================>...........] - ETA: 34s - loss: 0.9025 - accuracy: 0.551
#  94/140 [===================>..........] - ETA: 33s - loss: 0.9037 - accuracy: 0.551
#  95/140 [===================>..........] - ETA: 32s - loss: 0.9046 - accuracy: 0.550
#  96/140 [===================>..........] - ETA: 32s - loss: 0.9025 - accuracy: 0.552
#  97/140 [===================>..........] - ETA: 31s - loss: 0.9028 - accuracy: 0.551
#  98/140 [====================>.........] - ETA: 30s - loss: 0.9029 - accuracy: 0.550
#  99/140 [====================>.........] - ETA: 29s - loss: 0.9041 - accuracy: 0.549
# 100/140 [====================>.........] - ETA: 29s - loss: 0.9037 - accuracy: 0.550
# 101/140 [====================>.........] - ETA: 28s - loss: 0.9043 - accuracy: 0.550
# 102/140 [====================>.........] - ETA: 27s - loss: 0.9040 - accuracy: 0.550
# 103/140 [=====================>........] - ETA: 26s - loss: 0.9042 - accuracy: 0.549
# 104/140 [=====================>........] - ETA: 26s - loss: 0.9029 - accuracy: 0.550
# 105/140 [=====================>........] - ETA: 25s - loss: 0.9025 - accuracy: 0.551
# 106/140 [=====================>........] - ETA: 24s - loss: 0.9016 - accuracy: 0.551
# 107/140 [=====================>........] - ETA: 24s - loss: 0.9010 - accuracy: 0.552
# 108/140 [======================>.......] - ETA: 23s - loss: 0.9003 - accuracy: 0.552
# 109/140 [======================>.......] - ETA: 22s - loss: 0.9019 - accuracy: 0.552
# 110/140 [======================>.......] - ETA: 21s - loss: 0.9019 - accuracy: 0.553
# 111/140 [======================>.......] - ETA: 21s - loss: 0.9054 - accuracy: 0.551
# 112/140 [=======================>......] - ETA: 20s - loss: 0.9050 - accuracy: 0.551
# 113/140 [=======================>......] - ETA: 19s - loss: 0.9048 - accuracy: 0.550
# 114/140 [=======================>......] - ETA: 18s - loss: 0.9053 - accuracy: 0.550
# 115/140 [=======================>......] - ETA: 18s - loss: 0.9060 - accuracy: 0.549
# 116/140 [=======================>......] - ETA: 17s - loss: 0.9061 - accuracy: 0.548
# 117/140 [========================>.....] - ETA: 16s - loss: 0.9072 - accuracy: 0.547
# 118/140 [========================>.....] - ETA: 16s - loss: 0.9062 - accuracy: 0.548
# 119/140 [========================>.....] - ETA: 15s - loss: 0.9057 - accuracy: 0.547
# 120/140 [========================>.....] - ETA: 14s - loss: 0.9053 - accuracy: 0.547
# 121/140 [========================>.....] - ETA: 13s - loss: 0.9048 - accuracy: 0.548
# 122/140 [=========================>....] - ETA: 13s - loss: 0.9069 - accuracy: 0.547
# 123/140 [=========================>....] - ETA: 12s - loss: 0.9060 - accuracy: 0.548
# 124/140 [=========================>....] - ETA: 11s - loss: 0.9064 - accuracy: 0.548
# 125/140 [=========================>....] - ETA: 10s - loss: 0.9072 - accuracy: 0.548
# 126/140 [==========================>...] - ETA: 10s - loss: 0.9083 - accuracy: 0.547
# 127/140 [==========================>...] - ETA: 9s - loss: 0.9069 - accuracy: 0.547
# 128/140 [==========================>...] - ETA: 8s - loss: 0.9070 - accuracy: 0.54
# 129/140 [==========================>...] - ETA: 8s - loss: 0.9065 - accuracy: 0.54
# 130/140 [==========================>...] - ETA: 7s - loss: 0.9065 - accuracy: 0.54
# 131/140 [===========================>..] - ETA: 6s - loss: 0.9072 - accuracy: 0.54
# 132/140 [===========================>..] - ETA: 5s - loss: 0.9067 - accuracy: 0.54
# 133/140 [===========================>..] - ETA: 5s - loss: 0.9066 - accuracy: 0.54
# 134/140 [===========================>..] - ETA: 4s - loss: 0.9059 - accuracy: 0.54
# 135/140 [===========================>..] - ETA: 3s - loss: 0.9041 - accuracy: 0.54
# 136/140 [============================>.] - ETA: 2s - loss: 0.9041 - accuracy: 0.54
# 137/140 [============================>.] - ETA: 2s - loss: 0.9051 - accuracy: 0.54
# 138/140 [============================>.] - ETA: 1s - loss: 0.9046 - accuracy: 0.54
# 139/140 [============================>.] - ETA: 0s - loss: 0.9043 - accuracy: 0.54
# 140/140 [==============================] - ETA: 0s - loss: 0.9046 - accuracy: 0.54
# 140/140 [==============================] - 112s 798ms/step - loss: 0.9046 - accuracy: 0.5471 - val_loss: 0.9183 - val_accuracy: 0.5332
# Epoch 3/30
#
#   1/140 [..............................] - ETA: 2:02 - loss: 0.8376 - accuracy: 0.65
#   2/140 [..............................] - ETA: 1:40 - loss: 0.8529 - accuracy: 0.60
#   3/140 [..............................] - ETA: 1:39 - loss: 0.8301 - accuracy: 0.60
#   4/140 [..............................] - ETA: 1:38 - loss: 0.7931 - accuracy: 0.62
#   5/140 [>.............................] - ETA: 1:38 - loss: 0.7965 - accuracy: 0.61
#   6/140 [>.............................] - ETA: 1:37 - loss: 0.8561 - accuracy: 0.58
#   7/140 [>.............................] - ETA: 1:36 - loss: 0.8924 - accuracy: 0.55
#   8/140 [>.............................] - ETA: 1:36 - loss: 0.8921 - accuracy: 0.55
#   9/140 [>.............................] - ETA: 1:35 - loss: 0.8728 - accuracy: 0.55
#  10/140 [=>............................] - ETA: 1:34 - loss: 0.8678 - accuracy: 0.55
#  11/140 [=>............................] - ETA: 1:33 - loss: 0.8661 - accuracy: 0.55
#  12/140 [=>............................] - ETA: 1:33 - loss: 0.8718 - accuracy: 0.55
#  13/140 [=>............................] - ETA: 1:32 - loss: 0.8801 - accuracy: 0.54
#  14/140 [==>...........................] - ETA: 1:31 - loss: 0.8795 - accuracy: 0.54
#  15/140 [==>...........................] - ETA: 1:31 - loss: 0.8919 - accuracy: 0.54
#  16/140 [==>...........................] - ETA: 1:30 - loss: 0.8930 - accuracy: 0.54
#  17/140 [==>...........................] - ETA: 1:29 - loss: 0.8932 - accuracy: 0.54
#  18/140 [==>...........................] - ETA: 1:28 - loss: 0.8842 - accuracy: 0.54
#  19/140 [===>..........................] - ETA: 1:28 - loss: 0.8805 - accuracy: 0.55
#  20/140 [===>..........................] - ETA: 1:27 - loss: 0.8848 - accuracy: 0.54
#  21/140 [===>..........................] - ETA: 1:26 - loss: 0.8813 - accuracy: 0.54
#  22/140 [===>..........................] - ETA: 1:25 - loss: 0.8802 - accuracy: 0.55
#  23/140 [===>..........................] - ETA: 1:25 - loss: 0.8745 - accuracy: 0.54
#  24/140 [====>.........................] - ETA: 1:24 - loss: 0.8769 - accuracy: 0.54
#  25/140 [====>.........................] - ETA: 1:23 - loss: 0.8782 - accuracy: 0.54
#  26/140 [====>.........................] - ETA: 1:23 - loss: 0.8795 - accuracy: 0.54
#  27/140 [====>.........................] - ETA: 1:22 - loss: 0.8797 - accuracy: 0.54
#  28/140 [=====>........................] - ETA: 1:21 - loss: 0.8805 - accuracy: 0.54
#  29/140 [=====>........................] - ETA: 1:20 - loss: 0.8746 - accuracy: 0.54
#  30/140 [=====>........................] - ETA: 1:20 - loss: 0.8766 - accuracy: 0.54
#  31/140 [=====>........................] - ETA: 1:19 - loss: 0.8756 - accuracy: 0.54
#  32/140 [=====>........................] - ETA: 1:18 - loss: 0.8774 - accuracy: 0.54
#  33/140 [======>.......................] - ETA: 1:17 - loss: 0.8758 - accuracy: 0.54
#  34/140 [======>.......................] - ETA: 1:17 - loss: 0.8722 - accuracy: 0.54
#  35/140 [======>.......................] - ETA: 1:16 - loss: 0.8739 - accuracy: 0.54
#  36/140 [======>.......................] - ETA: 1:15 - loss: 0.8784 - accuracy: 0.54
#  37/140 [======>.......................] - ETA: 1:14 - loss: 0.8724 - accuracy: 0.55
#  38/140 [=======>......................] - ETA: 1:14 - loss: 0.8767 - accuracy: 0.55
#  39/140 [=======>......................] - ETA: 1:13 - loss: 0.8729 - accuracy: 0.55
#  40/140 [=======>......................] - ETA: 1:12 - loss: 0.8713 - accuracy: 0.55
#  41/140 [=======>......................] - ETA: 1:12 - loss: 0.8731 - accuracy: 0.55
#  42/140 [========>.....................] - ETA: 1:11 - loss: 0.8746 - accuracy: 0.55
#  43/140 [========>.....................] - ETA: 1:10 - loss: 0.8736 - accuracy: 0.55
#  44/140 [========>.....................] - ETA: 1:09 - loss: 0.8729 - accuracy: 0.55
#  45/140 [========>.....................] - ETA: 1:09 - loss: 0.8685 - accuracy: 0.55
#  46/140 [========>.....................] - ETA: 1:08 - loss: 0.8677 - accuracy: 0.55
#  47/140 [=========>....................] - ETA: 1:07 - loss: 0.8698 - accuracy: 0.55
#  48/140 [=========>....................] - ETA: 1:07 - loss: 0.8701 - accuracy: 0.55
#  49/140 [=========>....................] - ETA: 1:06 - loss: 0.8699 - accuracy: 0.55
#  50/140 [=========>....................] - ETA: 1:05 - loss: 0.8656 - accuracy: 0.55
#  51/140 [=========>....................] - ETA: 1:04 - loss: 0.8649 - accuracy: 0.55
#  52/140 [==========>...................] - ETA: 1:04 - loss: 0.8671 - accuracy: 0.55
#  53/140 [==========>...................] - ETA: 1:03 - loss: 0.8689 - accuracy: 0.55
#  54/140 [==========>...................] - ETA: 1:02 - loss: 0.8688 - accuracy: 0.55
#  55/140 [==========>...................] - ETA: 1:01 - loss: 0.8668 - accuracy: 0.56
#  56/140 [===========>..................] - ETA: 1:01 - loss: 0.8645 - accuracy: 0.56
#  57/140 [===========>..................] - ETA: 1:00 - loss: 0.8646 - accuracy: 0.56
#  58/140 [===========>..................] - ETA: 59s - loss: 0.8632 - accuracy: 0.5603
#  59/140 [===========>..................] - ETA: 58s - loss: 0.8670 - accuracy: 0.561
#  60/140 [===========>..................] - ETA: 58s - loss: 0.8663 - accuracy: 0.563
#  61/140 [============>.................] - ETA: 57s - loss: 0.8650 - accuracy: 0.564
#  62/140 [============>.................] - ETA: 56s - loss: 0.8669 - accuracy: 0.564
#  63/140 [============>.................] - ETA: 56s - loss: 0.8698 - accuracy: 0.561
#  64/140 [============>.................] - ETA: 55s - loss: 0.8718 - accuracy: 0.561
#  65/140 [============>.................] - ETA: 54s - loss: 0.8702 - accuracy: 0.563
#  66/140 [=============>................] - ETA: 53s - loss: 0.8683 - accuracy: 0.565
#  67/140 [=============>................] - ETA: 53s - loss: 0.8664 - accuracy: 0.567
#  68/140 [=============>................] - ETA: 52s - loss: 0.8651 - accuracy: 0.568
#  69/140 [=============>................] - ETA: 51s - loss: 0.8628 - accuracy: 0.571
#  70/140 [==============>...............] - ETA: 50s - loss: 0.8624 - accuracy: 0.572
#  71/140 [==============>...............] - ETA: 50s - loss: 0.8616 - accuracy: 0.573
#  72/140 [==============>...............] - ETA: 49s - loss: 0.8617 - accuracy: 0.573
#  73/140 [==============>...............] - ETA: 48s - loss: 0.8585 - accuracy: 0.574
#  74/140 [==============>...............] - ETA: 48s - loss: 0.8593 - accuracy: 0.574
#  75/140 [===============>..............] - ETA: 47s - loss: 0.8570 - accuracy: 0.575
#  76/140 [===============>..............] - ETA: 46s - loss: 0.8560 - accuracy: 0.575
#  77/140 [===============>..............] - ETA: 45s - loss: 0.8572 - accuracy: 0.575
#  78/140 [===============>..............] - ETA: 45s - loss: 0.8581 - accuracy: 0.575
#  79/140 [===============>..............] - ETA: 44s - loss: 0.8578 - accuracy: 0.575
#  80/140 [================>.............] - ETA: 43s - loss: 0.8579 - accuracy: 0.575
#  81/140 [================>.............] - ETA: 42s - loss: 0.8565 - accuracy: 0.574
#  82/140 [================>.............] - ETA: 42s - loss: 0.8544 - accuracy: 0.575
#  83/140 [================>.............] - ETA: 41s - loss: 0.8514 - accuracy: 0.577
#  84/140 [=================>............] - ETA: 40s - loss: 0.8555 - accuracy: 0.577
#  85/140 [=================>............] - ETA: 40s - loss: 0.8547 - accuracy: 0.578
#  86/140 [=================>............] - ETA: 39s - loss: 0.8539 - accuracy: 0.578
#  87/140 [=================>............] - ETA: 38s - loss: 0.8544 - accuracy: 0.578
#  88/140 [=================>............] - ETA: 37s - loss: 0.8549 - accuracy: 0.577
#  89/140 [==================>...........] - ETA: 37s - loss: 0.8548 - accuracy: 0.578
#  90/140 [==================>...........] - ETA: 36s - loss: 0.8552 - accuracy: 0.578
#  91/140 [==================>...........] - ETA: 35s - loss: 0.8571 - accuracy: 0.577
#  92/140 [==================>...........] - ETA: 34s - loss: 0.8572 - accuracy: 0.578
#  93/140 [==================>...........] - ETA: 34s - loss: 0.8556 - accuracy: 0.578
#  94/140 [===================>..........] - ETA: 33s - loss: 0.8572 - accuracy: 0.577
#  95/140 [===================>..........] - ETA: 32s - loss: 0.8580 - accuracy: 0.577
#  96/140 [===================>..........] - ETA: 32s - loss: 0.8597 - accuracy: 0.575
#  97/140 [===================>..........] - ETA: 31s - loss: 0.8598 - accuracy: 0.575
#  98/140 [====================>.........] - ETA: 30s - loss: 0.8579 - accuracy: 0.577
#  99/140 [====================>.........] - ETA: 29s - loss: 0.8586 - accuracy: 0.576
# 100/140 [====================>.........] - ETA: 29s - loss: 0.8583 - accuracy: 0.576
# 101/140 [====================>.........] - ETA: 28s - loss: 0.8583 - accuracy: 0.575
# 102/140 [====================>.........] - ETA: 27s - loss: 0.8581 - accuracy: 0.576
# 103/140 [=====================>........] - ETA: 26s - loss: 0.8584 - accuracy: 0.577
# 104/140 [=====================>........] - ETA: 26s - loss: 0.8578 - accuracy: 0.577
# 105/140 [=====================>........] - ETA: 25s - loss: 0.8567 - accuracy: 0.578
# 106/140 [=====================>........] - ETA: 24s - loss: 0.8577 - accuracy: 0.578
# 107/140 [=====================>........] - ETA: 24s - loss: 0.8564 - accuracy: 0.579
# 108/140 [======================>.......] - ETA: 23s - loss: 0.8567 - accuracy: 0.579
# 109/140 [======================>.......] - ETA: 22s - loss: 0.8550 - accuracy: 0.581
# 110/140 [======================>.......] - ETA: 21s - loss: 0.8536 - accuracy: 0.582
# 111/140 [======================>.......] - ETA: 21s - loss: 0.8528 - accuracy: 0.582
# 112/140 [=======================>......] - ETA: 20s - loss: 0.8530 - accuracy: 0.583
# 113/140 [=======================>......] - ETA: 19s - loss: 0.8520 - accuracy: 0.584
# 114/140 [=======================>......] - ETA: 18s - loss: 0.8535 - accuracy: 0.583
# 115/140 [=======================>......] - ETA: 18s - loss: 0.8528 - accuracy: 0.584
# 116/140 [=======================>......] - ETA: 17s - loss: 0.8518 - accuracy: 0.584
# 117/140 [========================>.....] - ETA: 16s - loss: 0.8532 - accuracy: 0.584
# 118/140 [========================>.....] - ETA: 16s - loss: 0.8517 - accuracy: 0.586
# 119/140 [========================>.....] - ETA: 15s - loss: 0.8513 - accuracy: 0.586
# 120/140 [========================>.....] - ETA: 14s - loss: 0.8513 - accuracy: 0.587
# 121/140 [========================>.....] - ETA: 13s - loss: 0.8505 - accuracy: 0.587
# 122/140 [=========================>....] - ETA: 13s - loss: 0.8505 - accuracy: 0.587
# 123/140 [=========================>....] - ETA: 12s - loss: 0.8512 - accuracy: 0.586
# 124/140 [=========================>....] - ETA: 11s - loss: 0.8508 - accuracy: 0.586
# 125/140 [=========================>....] - ETA: 10s - loss: 0.8506 - accuracy: 0.587
# 126/140 [==========================>...] - ETA: 10s - loss: 0.8485 - accuracy: 0.588
# 127/140 [==========================>...] - ETA: 9s - loss: 0.8476 - accuracy: 0.588
# 128/140 [==========================>...] - ETA: 8s - loss: 0.8472 - accuracy: 0.58
# 129/140 [==========================>...] - ETA: 8s - loss: 0.8476 - accuracy: 0.58
# 130/140 [==========================>...] - ETA: 7s - loss: 0.8474 - accuracy: 0.58
# 131/140 [===========================>..] - ETA: 6s - loss: 0.8466 - accuracy: 0.58
# 132/140 [===========================>..] - ETA: 5s - loss: 0.8465 - accuracy: 0.58
# 133/140 [===========================>..] - ETA: 5s - loss: 0.8469 - accuracy: 0.58
# 134/140 [===========================>..] - ETA: 4s - loss: 0.8468 - accuracy: 0.58
# 135/140 [===========================>..] - ETA: 3s - loss: 0.8469 - accuracy: 0.58
# 136/140 [============================>.] - ETA: 2s - loss: 0.8471 - accuracy: 0.58
# 137/140 [============================>.] - ETA: 2s - loss: 0.8449 - accuracy: 0.58
# 138/140 [============================>.] - ETA: 1s - loss: 0.8450 - accuracy: 0.58
# 139/140 [============================>.] - ETA: 0s - loss: 0.8454 - accuracy: 0.58
# 140/140 [==============================] - ETA: 0s - loss: 0.8462 - accuracy: 0.58
# 140/140 [==============================] - 112s 797ms/step - loss: 0.8462 - accuracy: 0.5860 - val_loss: 0.9540 - val_accuracy: 0.5317
# Epoch 4/30
#
#   1/140 [..............................] - ETA: 1:58 - loss: 0.7375 - accuracy: 0.59
#   2/140 [..............................] - ETA: 1:40 - loss: 0.8507 - accuracy: 0.57
#   3/140 [..............................] - ETA: 1:39 - loss: 0.8770 - accuracy: 0.55
#   4/140 [..............................] - ETA: 1:38 - loss: 0.8629 - accuracy: 0.55
#   5/140 [>.............................] - ETA: 1:38 - loss: 0.8469 - accuracy: 0.56
#   6/140 [>.............................] - ETA: 1:37 - loss: 0.8215 - accuracy: 0.59
#   7/140 [>.............................] - ETA: 1:36 - loss: 0.8255 - accuracy: 0.59
#   8/140 [>.............................] - ETA: 1:36 - loss: 0.8141 - accuracy: 0.59
#   9/140 [>.............................] - ETA: 1:35 - loss: 0.8166 - accuracy: 0.59
#  10/140 [=>............................] - ETA: 1:34 - loss: 0.8414 - accuracy: 0.57
#  11/140 [=>............................] - ETA: 1:33 - loss: 0.8351 - accuracy: 0.58
#  12/140 [=>............................] - ETA: 1:33 - loss: 0.8434 - accuracy: 0.57
#  13/140 [=>............................] - ETA: 1:32 - loss: 0.8385 - accuracy: 0.58
#  14/140 [==>...........................] - ETA: 1:31 - loss: 0.8431 - accuracy: 0.58
#  15/140 [==>...........................] - ETA: 1:31 - loss: 0.8342 - accuracy: 0.58
#  16/140 [==>...........................] - ETA: 1:30 - loss: 0.8222 - accuracy: 0.59
#  17/140 [==>...........................] - ETA: 1:29 - loss: 0.8236 - accuracy: 0.59
#  18/140 [==>...........................] - ETA: 1:28 - loss: 0.8162 - accuracy: 0.59
#  19/140 [===>..........................] - ETA: 1:28 - loss: 0.8224 - accuracy: 0.58
#  20/140 [===>..........................] - ETA: 1:27 - loss: 0.8193 - accuracy: 0.59
#  21/140 [===>..........................] - ETA: 1:26 - loss: 0.8180 - accuracy: 0.59
#  22/140 [===>..........................] - ETA: 1:25 - loss: 0.8150 - accuracy: 0.59
#  23/140 [===>..........................] - ETA: 1:25 - loss: 0.8090 - accuracy: 0.59
#  24/140 [====>.........................] - ETA: 1:24 - loss: 0.8177 - accuracy: 0.59
#  25/140 [====>.........................] - ETA: 1:23 - loss: 0.8147 - accuracy: 0.59
#  26/140 [====>.........................] - ETA: 1:23 - loss: 0.8072 - accuracy: 0.60
#  27/140 [====>.........................] - ETA: 1:22 - loss: 0.8075 - accuracy: 0.60
#  28/140 [=====>........................] - ETA: 1:21 - loss: 0.8112 - accuracy: 0.60
#  29/140 [=====>........................] - ETA: 1:20 - loss: 0.8079 - accuracy: 0.60
#  30/140 [=====>........................] - ETA: 1:20 - loss: 0.8137 - accuracy: 0.60
#  31/140 [=====>........................] - ETA: 1:19 - loss: 0.8146 - accuracy: 0.60
#  32/140 [=====>........................] - ETA: 1:18 - loss: 0.8169 - accuracy: 0.59
#  33/140 [======>.......................] - ETA: 1:17 - loss: 0.8148 - accuracy: 0.60
#  34/140 [======>.......................] - ETA: 1:17 - loss: 0.8157 - accuracy: 0.60
#  35/140 [======>.......................] - ETA: 1:16 - loss: 0.8124 - accuracy: 0.60
#  36/140 [======>.......................] - ETA: 1:15 - loss: 0.8113 - accuracy: 0.60
#  37/140 [======>.......................] - ETA: 1:14 - loss: 0.8100 - accuracy: 0.60
#  38/140 [=======>......................] - ETA: 1:14 - loss: 0.8126 - accuracy: 0.60
#  39/140 [=======>......................] - ETA: 1:13 - loss: 0.8068 - accuracy: 0.61
#  40/140 [=======>......................] - ETA: 1:12 - loss: 0.8039 - accuracy: 0.61
#  41/140 [=======>......................] - ETA: 1:12 - loss: 0.8018 - accuracy: 0.61
#  42/140 [========>.....................] - ETA: 1:11 - loss: 0.7979 - accuracy: 0.61
#  43/140 [========>.....................] - ETA: 1:10 - loss: 0.7956 - accuracy: 0.61
#  44/140 [========>.....................] - ETA: 1:09 - loss: 0.7904 - accuracy: 0.62
#  45/140 [========>.....................] - ETA: 1:09 - loss: 0.7923 - accuracy: 0.62
#  46/140 [========>.....................] - ETA: 1:08 - loss: 0.7980 - accuracy: 0.61
#  47/140 [=========>....................] - ETA: 1:07 - loss: 0.7966 - accuracy: 0.61
#  48/140 [=========>....................] - ETA: 1:06 - loss: 0.7991 - accuracy: 0.61
#  49/140 [=========>....................] - ETA: 1:06 - loss: 0.8000 - accuracy: 0.61
#  50/140 [=========>....................] - ETA: 1:05 - loss: 0.8020 - accuracy: 0.61
#  51/140 [=========>....................] - ETA: 1:04 - loss: 0.8016 - accuracy: 0.61
#  52/140 [==========>...................] - ETA: 1:04 - loss: 0.7990 - accuracy: 0.62
#  53/140 [==========>...................] - ETA: 1:03 - loss: 0.7995 - accuracy: 0.62
#  54/140 [==========>...................] - ETA: 1:02 - loss: 0.7994 - accuracy: 0.62
#  55/140 [==========>...................] - ETA: 1:01 - loss: 0.7982 - accuracy: 0.62
#  56/140 [===========>..................] - ETA: 1:01 - loss: 0.7963 - accuracy: 0.62
#  57/140 [===========>..................] - ETA: 1:00 - loss: 0.7939 - accuracy: 0.62
#  58/140 [===========>..................] - ETA: 59s - loss: 0.7903 - accuracy: 0.6266
#  59/140 [===========>..................] - ETA: 58s - loss: 0.7904 - accuracy: 0.625
#  60/140 [===========>..................] - ETA: 58s - loss: 0.7906 - accuracy: 0.625
#  61/140 [============>.................] - ETA: 57s - loss: 0.7888 - accuracy: 0.626
#  62/140 [============>.................] - ETA: 56s - loss: 0.7916 - accuracy: 0.625
#  63/140 [============>.................] - ETA: 56s - loss: 0.7898 - accuracy: 0.626
#  64/140 [============>.................] - ETA: 55s - loss: 0.7899 - accuracy: 0.627
#  65/140 [============>.................] - ETA: 54s - loss: 0.7894 - accuracy: 0.627
#  66/140 [=============>................] - ETA: 53s - loss: 0.7865 - accuracy: 0.629
#  67/140 [=============>................] - ETA: 53s - loss: 0.7852 - accuracy: 0.629
#  68/140 [=============>................] - ETA: 52s - loss: 0.7891 - accuracy: 0.629
#  69/140 [=============>................] - ETA: 51s - loss: 0.7927 - accuracy: 0.630
#  70/140 [==============>...............] - ETA: 50s - loss: 0.7934 - accuracy: 0.629
#  71/140 [==============>...............] - ETA: 50s - loss: 0.7934 - accuracy: 0.628
#  72/140 [==============>...............] - ETA: 49s - loss: 0.7923 - accuracy: 0.630
#  73/140 [==============>...............] - ETA: 48s - loss: 0.7921 - accuracy: 0.630
#  74/140 [==============>...............] - ETA: 48s - loss: 0.7909 - accuracy: 0.631
#  75/140 [===============>..............] - ETA: 47s - loss: 0.7915 - accuracy: 0.630
#  76/140 [===============>..............] - ETA: 46s - loss: 0.7910 - accuracy: 0.629
#  77/140 [===============>..............] - ETA: 45s - loss: 0.7901 - accuracy: 0.631
#  78/140 [===============>..............] - ETA: 45s - loss: 0.7890 - accuracy: 0.632
#  79/140 [===============>..............] - ETA: 44s - loss: 0.7873 - accuracy: 0.633
#  80/140 [================>.............] - ETA: 43s - loss: 0.7847 - accuracy: 0.635
#  81/140 [================>.............] - ETA: 42s - loss: 0.7829 - accuracy: 0.636
#  82/140 [================>.............] - ETA: 42s - loss: 0.7827 - accuracy: 0.636
#  83/140 [================>.............] - ETA: 41s - loss: 0.7832 - accuracy: 0.635
#  84/140 [=================>............] - ETA: 40s - loss: 0.7806 - accuracy: 0.635
#  85/140 [=================>............] - ETA: 40s - loss: 0.7780 - accuracy: 0.636
#  86/140 [=================>............] - ETA: 39s - loss: 0.7752 - accuracy: 0.638
#  87/140 [=================>............] - ETA: 38s - loss: 0.7732 - accuracy: 0.638
#  88/140 [=================>............] - ETA: 37s - loss: 0.7732 - accuracy: 0.638
#  89/140 [==================>...........] - ETA: 37s - loss: 0.7716 - accuracy: 0.639
#  90/140 [==================>...........] - ETA: 36s - loss: 0.7708 - accuracy: 0.638
#  91/140 [==================>...........] - ETA: 35s - loss: 0.7717 - accuracy: 0.639
#  92/140 [==================>...........] - ETA: 34s - loss: 0.7700 - accuracy: 0.641
#  93/140 [==================>...........] - ETA: 34s - loss: 0.7704 - accuracy: 0.641
#  94/140 [===================>..........] - ETA: 33s - loss: 0.7697 - accuracy: 0.642
#  95/140 [===================>..........] - ETA: 32s - loss: 0.7697 - accuracy: 0.642
#  96/140 [===================>..........] - ETA: 32s - loss: 0.7690 - accuracy: 0.643
#  97/140 [===================>..........] - ETA: 31s - loss: 0.7668 - accuracy: 0.644
#  98/140 [====================>.........] - ETA: 30s - loss: 0.7637 - accuracy: 0.645
#  99/140 [====================>.........] - ETA: 29s - loss: 0.7620 - accuracy: 0.647
# 100/140 [====================>.........] - ETA: 29s - loss: 0.7620 - accuracy: 0.646
# 101/140 [====================>.........] - ETA: 28s - loss: 0.7624 - accuracy: 0.645
# 102/140 [====================>.........] - ETA: 27s - loss: 0.7609 - accuracy: 0.646
# 103/140 [=====================>........] - ETA: 26s - loss: 0.7614 - accuracy: 0.645
# 104/140 [=====================>........] - ETA: 26s - loss: 0.7591 - accuracy: 0.646
# 105/140 [=====================>........] - ETA: 25s - loss: 0.7578 - accuracy: 0.647
# 106/140 [=====================>........] - ETA: 24s - loss: 0.7581 - accuracy: 0.647
# 107/140 [=====================>........] - ETA: 24s - loss: 0.7571 - accuracy: 0.648
# 108/140 [======================>.......] - ETA: 23s - loss: 0.7590 - accuracy: 0.647
# 109/140 [======================>.......] - ETA: 22s - loss: 0.7561 - accuracy: 0.648
# 110/140 [======================>.......] - ETA: 21s - loss: 0.7564 - accuracy: 0.648
# 111/140 [======================>.......] - ETA: 21s - loss: 0.7548 - accuracy: 0.649
# 112/140 [=======================>......] - ETA: 20s - loss: 0.7537 - accuracy: 0.650
# 113/140 [=======================>......] - ETA: 19s - loss: 0.7531 - accuracy: 0.651
# 114/140 [=======================>......] - ETA: 18s - loss: 0.7523 - accuracy: 0.651
# 115/140 [=======================>......] - ETA: 18s - loss: 0.7527 - accuracy: 0.651
# 116/140 [=======================>......] - ETA: 17s - loss: 0.7513 - accuracy: 0.652
# 117/140 [========================>.....] - ETA: 16s - loss: 0.7504 - accuracy: 0.653
# 118/140 [========================>.....] - ETA: 16s - loss: 0.7511 - accuracy: 0.653
# 119/140 [========================>.....] - ETA: 15s - loss: 0.7506 - accuracy: 0.653
# 120/140 [========================>.....] - ETA: 14s - loss: 0.7497 - accuracy: 0.654
# 121/140 [========================>.....] - ETA: 13s - loss: 0.7493 - accuracy: 0.654
# 122/140 [=========================>....] - ETA: 13s - loss: 0.7488 - accuracy: 0.654
# 123/140 [=========================>....] - ETA: 12s - loss: 0.7476 - accuracy: 0.655
# 124/140 [=========================>....] - ETA: 11s - loss: 0.7468 - accuracy: 0.655
# 125/140 [=========================>....] - ETA: 10s - loss: 0.7455 - accuracy: 0.656
# 126/140 [==========================>...] - ETA: 10s - loss: 0.7455 - accuracy: 0.656
# ...
#  14/140 [==>...........................] - ETA: 32s - loss: 1.6904 - accuracy: 0.732
#  15/140 [==>...........................] - ETA: 31s - loss: 1.7196 - accuracy: 0.731
#  16/140 [==>...........................] - ETA: 31s - loss: 1.7108 - accuracy: 0.734
#  17/140 [==>...........................] - ETA: 31s - loss: 1.7460 - accuracy: 0.731
#  18/140 [==>...........................] - ETA: 31s - loss: 1.8387 - accuracy: 0.724
#  19/140 [===>..........................] - ETA: 30s - loss: 1.8659 - accuracy: 0.722
#  20/140 [===>..........................] - ETA: 30s - loss: 1.8946 - accuracy: 0.721
#  21/140 [===>..........................] - ETA: 30s - loss: 1.8664 - accuracy: 0.718
#  22/140 [===>..........................] - ETA: 30s - loss: 1.8831 - accuracy: 0.713
#  23/140 [===>..........................] - ETA: 29s - loss: 1.9069 - accuracy: 0.710
#  24/140 [====>.........................] - ETA: 29s - loss: 1.9025 - accuracy: 0.709
#  25/140 [====>.........................] - ETA: 29s - loss: 1.8745 - accuracy: 0.710
#  26/140 [====>.........................] - ETA: 29s - loss: 1.8369 - accuracy: 0.713
#  27/140 [====>.........................] - ETA: 28s - loss: 1.8198 - accuracy: 0.713
#  28/140 [=====>........................] - ETA: 28s - loss: 1.8392 - accuracy: 0.712
#  29/140 [=====>........................] - ETA: 28s - loss: 1.8006 - accuracy: 0.718
#  30/140 [=====>........................] - ETA: 28s - loss: 1.8054 - accuracy: 0.716
#  31/140 [=====>........................] - ETA: 27s - loss: 1.8002 - accuracy: 0.717
#  32/140 [=====>........................] - ETA: 27s - loss: 1.7812 - accuracy: 0.713
#  33/140 [======>.......................] - ETA: 27s - loss: 1.7722 - accuracy: 0.715
#  34/140 [======>.......................] - ETA: 27s - loss: 1.7589 - accuracy: 0.718
#  35/140 [======>.......................] - ETA: 26s - loss: 1.7768 - accuracy: 0.713
#  36/140 [======>.......................] - ETA: 26s - loss: 1.7590 - accuracy: 0.715
#  37/140 [======>.......................] - ETA: 26s - loss: 1.7490 - accuracy: 0.715
#  38/140 [=======>......................] - ETA: 26s - loss: 1.7406 - accuracy: 0.714
#  39/140 [=======>......................] - ETA: 25s - loss: 1.7224 - accuracy: 0.716
#  40/140 [=======>......................] - ETA: 25s - loss: 1.7313 - accuracy: 0.714
#  41/140 [=======>......................] - ETA: 25s - loss: 1.7231 - accuracy: 0.717
#  42/140 [========>.....................] - ETA: 24s - loss: 1.7274 - accuracy: 0.718
#  43/140 [========>.....................] - ETA: 24s - loss: 1.7293 - accuracy: 0.717
#  44/140 [========>.....................] - ETA: 24s - loss: 1.7299 - accuracy: 0.717
#  45/140 [========>.....................] - ETA: 24s - loss: 1.7304 - accuracy: 0.718
#  46/140 [========>.....................] - ETA: 23s - loss: 1.7089 - accuracy: 0.721
#  47/140 [=========>....................] - ETA: 23s - loss: 1.7093 - accuracy: 0.720
#  48/140 [=========>....................] - ETA: 23s - loss: 1.7154 - accuracy: 0.716
#  49/140 [=========>....................] - ETA: 23s - loss: 1.7024 - accuracy: 0.717
#  50/140 [=========>....................] - ETA: 22s - loss: 1.7075 - accuracy: 0.715
#  51/140 [=========>....................] - ETA: 22s - loss: 1.7275 - accuracy: 0.713
#  52/140 [==========>...................] - ETA: 22s - loss: 1.7320 - accuracy: 0.714
#  53/140 [==========>...................] - ETA: 22s - loss: 1.7230 - accuracy: 0.716
#  54/140 [==========>...................] - ETA: 21s - loss: 1.7146 - accuracy: 0.718
#  55/140 [==========>...................] - ETA: 21s - loss: 1.7272 - accuracy: 0.717
#  56/140 [===========>..................] - ETA: 21s - loss: 1.7472 - accuracy: 0.714
#  57/140 [===========>..................] - ETA: 21s - loss: 1.7453 - accuracy: 0.714
#  58/140 [===========>..................] - ETA: 20s - loss: 1.7486 - accuracy: 0.714
#  59/140 [===========>..................] - ETA: 20s - loss: 1.7417 - accuracy: 0.715
#  60/140 [===========>..................] - ETA: 20s - loss: 1.7345 - accuracy: 0.715
#  61/140 [============>.................] - ETA: 20s - loss: 1.7310 - accuracy: 0.716
#  62/140 [============>.................] - ETA: 19s - loss: 1.7233 - accuracy: 0.718
#  63/140 [============>.................] - ETA: 19s - loss: 1.7184 - accuracy: 0.718
#  64/140 [============>.................] - ETA: 19s - loss: 1.7089 - accuracy: 0.718
#  65/140 [============>.................] - ETA: 19s - loss: 1.7026 - accuracy: 0.718
#  66/140 [=============>................] - ETA: 18s - loss: 1.7124 - accuracy: 0.716
#  67/140 [=============>................] - ETA: 18s - loss: 1.7114 - accuracy: 0.716
#  68/140 [=============>................] - ETA: 18s - loss: 1.7122 - accuracy: 0.716
#  69/140 [=============>................] - ETA: 18s - loss: 1.7026 - accuracy: 0.716
#  70/140 [==============>...............] - ETA: 17s - loss: 1.7037 - accuracy: 0.715
#  71/140 [==============>...............] - ETA: 17s - loss: 1.7260 - accuracy: 0.716
#  72/140 [==============>...............] - ETA: 17s - loss: 1.7367 - accuracy: 0.714
#  73/140 [==============>...............] - ETA: 17s - loss: 1.7410 - accuracy: 0.714
#  74/140 [==============>...............] - ETA: 16s - loss: 1.7495 - accuracy: 0.712
#  75/140 [===============>..............] - ETA: 16s - loss: 1.7550 - accuracy: 0.710
#  76/140 [===============>..............] - ETA: 16s - loss: 1.7365 - accuracy: 0.713
#  77/140 [===============>..............] - ETA: 16s - loss: 1.7301 - accuracy: 0.713
#  78/140 [===============>..............] - ETA: 15s - loss: 1.7256 - accuracy: 0.714
#  79/140 [===============>..............] - ETA: 15s - loss: 1.7205 - accuracy: 0.714
#  80/140 [================>.............] - ETA: 15s - loss: 1.7233 - accuracy: 0.715
#  81/140 [================>.............] - ETA: 15s - loss: 1.7188 - accuracy: 0.715
#  82/140 [================>.............] - ETA: 14s - loss: 1.7148 - accuracy: 0.716
#  83/140 [================>.............] - ETA: 14s - loss: 1.7017 - accuracy: 0.717
#  84/140 [=================>............] - ETA: 14s - loss: 1.7058 - accuracy: 0.718
#  85/140 [=================>............] - ETA: 14s - loss: 1.7021 - accuracy: 0.719
#  86/140 [=================>............] - ETA: 13s - loss: 1.7024 - accuracy: 0.719
#  87/140 [=================>............] - ETA: 13s - loss: 1.6978 - accuracy: 0.721
#  88/140 [=================>............] - ETA: 13s - loss: 1.7024 - accuracy: 0.720
#  89/140 [==================>...........] - ETA: 12s - loss: 1.6961 - accuracy: 0.721
#  90/140 [==================>...........] - ETA: 12s - loss: 1.6992 - accuracy: 0.721
#  91/140 [==================>...........] - ETA: 12s - loss: 1.7003 - accuracy: 0.721
#  92/140 [==================>...........] - ETA: 12s - loss: 1.6891 - accuracy: 0.722
#  93/140 [==================>...........] - ETA: 11s - loss: 1.6933 - accuracy: 0.722
#  94/140 [===================>..........] - ETA: 11s - loss: 1.6967 - accuracy: 0.722
#  95/140 [===================>..........] - ETA: 11s - loss: 1.6997 - accuracy: 0.721
#  96/140 [===================>..........] - ETA: 11s - loss: 1.6884 - accuracy: 0.722
#  97/140 [===================>..........] - ETA: 10s - loss: 1.6795 - accuracy: 0.722
#  98/140 [====================>.........] - ETA: 10s - loss: 1.6739 - accuracy: 0.723
#  99/140 [====================>.........] - ETA: 10s - loss: 1.6886 - accuracy: 0.722
# 100/140 [====================>.........] - ETA: 10s - loss: 1.6885 - accuracy: 0.722
# 101/140 [====================>.........] - ETA: 9s - loss: 1.7015 - accuracy: 0.721
# 102/140 [====================>.........] - ETA: 9s - loss: 1.7050 - accuracy: 0.72
# 103/140 [=====================>........] - ETA: 9s - loss: 1.7108 - accuracy: 0.72
# 104/140 [=====================>........] - ETA: 9s - loss: 1.7060 - accuracy: 0.72
# 105/140 [=====================>........] - ETA: 8s - loss: 1.7061 - accuracy: 0.72
# 106/140 [=====================>........] - ETA: 8s - loss: 1.7088 - accuracy: 0.72
# 107/140 [=====================>........] - ETA: 8s - loss: 1.7048 - accuracy: 0.72
# 108/140 [======================>.......] - ETA: 8s - loss: 1.7107 - accuracy: 0.71
# 109/140 [======================>.......] - ETA: 7s - loss: 1.7043 - accuracy: 0.71
# 110/140 [======================>.......] - ETA: 7s - loss: 1.7069 - accuracy: 0.71
# 111/140 [======================>.......] - ETA: 7s - loss: 1.7091 - accuracy: 0.72
# 112/140 [=======================>......] - ETA: 7s - loss: 1.7150 - accuracy: 0.72
# 113/140 [=======================>......] - ETA: 6s - loss: 1.7182 - accuracy: 0.71
# 114/140 [=======================>......] - ETA: 6s - loss: 1.7206 - accuracy: 0.71
# 115/140 [=======================>......] - ETA: 6s - loss: 1.7089 - accuracy: 0.72
# 116/140 [=======================>......] - ETA: 6s - loss: 1.7160 - accuracy: 0.72
# 117/140 [========================>.....] - ETA: 5s - loss: 1.7065 - accuracy: 0.72
# 118/140 [========================>.....] - ETA: 5s - loss: 1.7032 - accuracy: 0.72
# 119/140 [========================>.....] - ETA: 5s - loss: 1.6990 - accuracy: 0.72
# 120/140 [========================>.....] - ETA: 5s - loss: 1.6947 - accuracy: 0.72
# 121/140 [========================>.....] - ETA: 4s - loss: 1.6865 - accuracy: 0.72
# 122/140 [=========================>....] - ETA: 4s - loss: 1.6841 - accuracy: 0.72
# 123/140 [=========================>....] - ETA: 4s - loss: 1.6885 - accuracy: 0.72
# 124/140 [=========================>....] - ETA: 4s - loss: 1.6841 - accuracy: 0.72
# 125/140 [=========================>....] - ETA: 3s - loss: 1.6849 - accuracy: 0.72
# 126/140 [==========================>...] - ETA: 3s - loss: 1.6896 - accuracy: 0.72
# 127/140 [==========================>...] - ETA: 3s - loss: 1.6844 - accuracy: 0.72
# 128/140 [==========================>...] - ETA: 3s - loss: 1.6778 - accuracy: 0.72
# 129/140 [==========================>...] - ETA: 2s - loss: 1.6764 - accuracy: 0.72
# 130/140 [==========================>...] - ETA: 2s - loss: 1.6745 - accuracy: 0.72
# 131/140 [===========================>..] - ETA: 2s - loss: 1.6667 - accuracy: 0.72
# 132/140 [===========================>..] - ETA: 2s - loss: 1.6605 - accuracy: 0.72
# 133/140 [===========================>..] - ETA: 1s - loss: 1.6602 - accuracy: 0.72
# 134/140 [===========================>..] - ETA: 1s - loss: 1.6575 - accuracy: 0.72
# 135/140 [===========================>..] - ETA: 1s - loss: 1.6566 - accuracy: 0.72
# 136/140 [============================>.] - ETA: 1s - loss: 1.6639 - accuracy: 0.72
# 137/140 [============================>.] - ETA: 0s - loss: 1.6618 - accuracy: 0.72
# 138/140 [============================>.] - ETA: 0s - loss: 1.6597 - accuracy: 0.72
# 139/140 [============================>.] - ETA: 0s - loss: 1.6579 - accuracy: 0.72
# 140/140 [==============================] - ETA: 0s - loss: 1.6646 - accuracy: 0.72
# 140/140 [==============================] - 38s 273ms/step - loss: 1.6646 - accuracy: 0.7267
#
#  1/40 [..............................] - ETA: 12s - loss: 11.6207 - accuracy: 0.18
#  2/40 [>.............................] - ETA: 9s - loss: 12.7634 - accuracy: 0.1406
#  3/40 [=>............................] - ETA: 9s - loss: 14.2315 - accuracy: 0.104
#  4/40 [==>...........................] - ETA: 9s - loss: 14.8534 - accuracy: 0.085
#  5/40 [==>...........................] - ETA: 8s - loss: 15.7023 - accuracy: 0.068
#  6/40 [===>..........................] - ETA: 8s - loss: 15.3950 - accuracy: 0.083
#  7/40 [====>.........................] - ETA: 8s - loss: 13.2209 - accuracy: 0.205
#  8/40 [=====>........................] - ETA: 8s - loss: 11.5684 - accuracy: 0.304
#  9/40 [=====>........................] - ETA: 7s - loss: 10.2923 - accuracy: 0.375
# 10/40 [======>.......................] - ETA: 7s - loss: 9.2826 - accuracy: 0.434
# 11/40 [=======>......................] - ETA: 7s - loss: 8.4389 - accuracy: 0.48
# 12/40 [========>.....................] - ETA: 7s - loss: 7.7357 - accuracy: 0.52
# 13/40 [========>.....................] - ETA: 6s - loss: 7.1409 - accuracy: 0.56
# 14/40 [=========>....................] - ETA: 6s - loss: 6.6316 - accuracy: 0.59
# 15/40 [==========>...................] - ETA: 6s - loss: 6.1896 - accuracy: 0.62
# 16/40 [===========>..................] - ETA: 6s - loss: 5.8028 - accuracy: 0.64
# 17/40 [===========>..................] - ETA: 5s - loss: 5.4615 - accuracy: 0.66
# 18/40 [============>.................] - ETA: 5s - loss: 5.1582 - accuracy: 0.68
# 19/40 [=============>................] - ETA: 5s - loss: 4.8924 - accuracy: 0.70
# 20/40 [==============>...............] - ETA: 5s - loss: 4.6478 - accuracy: 0.71
# 21/40 [==============>...............] - ETA: 4s - loss: 4.4266 - accuracy: 0.72
# 22/40 [===============>..............] - ETA: 4s - loss: 4.2300 - accuracy: 0.74
# 23/40 [================>.............] - ETA: 4s - loss: 4.0461 - accuracy: 0.75
# 24/40 [=================>............] - ETA: 4s - loss: 3.8788 - accuracy: 0.76
# 25/40 [=================>............] - ETA: 3s - loss: 3.7339 - accuracy: 0.76
# 26/40 [==================>...........] - ETA: 3s - loss: 3.6097 - accuracy: 0.77
# 27/40 [===================>..........] - ETA: 3s - loss: 3.7410 - accuracy: 0.75
# 28/40 [====================>.........] - ETA: 3s - loss: 3.8146 - accuracy: 0.73
# 29/40 [====================>.........] - ETA: 2s - loss: 3.9437 - accuracy: 0.71
# 30/40 [=====================>........] - ETA: 2s - loss: 4.0704 - accuracy: 0.70
# 31/40 [======================>.......] - ETA: 2s - loss: 4.2156 - accuracy: 0.68
# 32/40 [=======================>......] - ETA: 2s - loss: 4.2975 - accuracy: 0.66
# 33/40 [=======================>......] - ETA: 1s - loss: 4.4447 - accuracy: 0.65
# 34/40 [========================>.....] - ETA: 1s - loss: 4.5952 - accuracy: 0.63
# 35/40 [=========================>....] - ETA: 1s - loss: 4.6682 - accuracy: 0.62
# 36/40 [==========================>...] - ETA: 1s - loss: 4.7871 - accuracy: 0.61
# 37/40 [==========================>...] - ETA: 0s - loss: 4.8466 - accuracy: 0.60
# 38/40 [===========================>..] - ETA: 0s - loss: 4.9684 - accuracy: 0.58
# 39/40 [============================>.] - ETA: 0s - loss: 5.0076 - accuracy: 0.58
# 40/40 [==============================] - ETA: 0s - loss: 5.0420 - accuracy: 0.57
# 40/40 [==============================] - 10s 254ms/step - loss: 5.0420 - accuracy: 0.5723
#
#  1/21 [>.............................] - ETA: 8s - loss: 1.7286 - accuracy: 0.75
#  2/21 [=>............................] - ETA: 4s - loss: 1.7089 - accuracy: 0.71
#  3/21 [===>..........................] - ETA: 4s - loss: 1.5518 - accuracy: 0.73
#  4/21 [====>.........................] - ETA: 4s - loss: 1.5599 - accuracy: 0.74
#  5/21 [======>.......................] - ETA: 4s - loss: 1.8081 - accuracy: 0.71
#  6/21 [=======>......................] - ETA: 3s - loss: 1.9002 - accuracy: 0.72
#  7/21 [=========>....................] - ETA: 3s - loss: 1.9455 - accuracy: 0.71
#  8/21 [==========>...................] - ETA: 3s - loss: 2.0885 - accuracy: 0.70
#  9/21 [===========>..................] - ETA: 3s - loss: 2.0327 - accuracy: 0.71
# 10/21 [=============>................] - ETA: 2s - loss: 2.0880 - accuracy: 0.71
# 11/21 [==============>...............] - ETA: 2s - loss: 2.1649 - accuracy: 0.71
# 12/21 [================>.............] - ETA: 2s - loss: 2.0690 - accuracy: 0.71
# 13/21 [=================>............] - ETA: 2s - loss: 1.9930 - accuracy: 0.72
# 14/21 [===================>..........] - ETA: 1s - loss: 1.9956 - accuracy: 0.72
# 15/21 [====================>.........] - ETA: 1s - loss: 2.0428 - accuracy: 0.72
# 16/21 [=====================>........] - ETA: 1s - loss: 2.0353 - accuracy: 0.72
# 17/21 [=======================>......] - ETA: 1s - loss: 2.0310 - accuracy: 0.72
# 18/21 [========================>.....] - ETA: 0s - loss: 1.9978 - accuracy: 0.72
# 19/21 [==========================>...] - ETA: 0s - loss: 1.9763 - accuracy: 0.71
# 20/21 [===========================>..] - ETA: 0s - loss: 1.9169 - accuracy: 0.72
# 21/21 [==============================] - ETA: 0s - loss: 1.9442 - accuracy: 0.72
# 21/21 [==============================] - 5s 253ms/step - loss: 1.9442 - accuracy: 0.7218

# %%
# !zip -0 -r ConvNeXtBase.zip ./*
